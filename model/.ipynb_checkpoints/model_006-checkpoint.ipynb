# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import LearningRateScheduler
import math

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv("../DataSets/bitcoin_prices5.csv")
df['timestamp'] = pd.to_datetime(df['timestamp'], unit='s')
df_chart = df.copy()
df
# Out:
#                timestamp     -1min          sma7         sma25         sma50  \
# 0    2023-04-13 12:27:00       NaN           NaN           NaN           NaN
# 1    2023-04-13 12:28:00  30216.29           NaN           NaN           NaN
# 2    2023-04-13 12:29:00  30213.57           NaN           NaN           NaN
# 3    2023-04-13 12:30:00  30214.46           NaN           NaN           NaN
# 4    2023-04-13 12:31:00  30256.32           NaN           NaN           NaN
# ...                  ...       ...           ...           ...           ...
# 1996 2023-04-14 21:43:00  30512.85  30513.616485  30486.927322  30452.803016
# 1997 2023-04-14 21:44:00  30516.24  30513.265558  30487.896629  30453.970156
# 1998 2023-04-14 21:45:00  30511.16  30512.064764  30488.575164  30454.987953
# 1999 2023-04-14 21:46:00  30504.86  30510.682655  30489.127758  30455.935994
# 2000 2023-04-14 21:47:00  30502.39  30509.499419  30489.658647  30456.865274
#
#               ema7         ema25         ema50     price
# 0              NaN           NaN           NaN  30216.29
# 1              NaN           NaN           NaN  30213.57
# 2              NaN           NaN           NaN  30214.46
# 3              NaN           NaN           NaN  30256.32
# 4              NaN           NaN           NaN  30237.66
# ...            ...           ...           ...       ...
# 1996  30518.259932  30503.266014  30486.248963  30516.24
# 1997  30516.484949  30503.873244  30487.225866  30511.16
# 1998  30513.578712  30503.949148  30487.917401  30504.86
# 1999  30510.781534  30503.829213  30488.484954  30502.39
# 2000  30508.686150  30503.719274  30489.030642  30502.40
#
# [2001 rows x 9 columns]

# %% [markdown]
# ## Dataset Summary

# %%
df_chart['timestamp'] = pd.to_datetime(df_chart['timestamp'])
df_chart.set_index('timestamp', inplace=True)

plt.figure(figsize=(15,5))
plt.plot(df_chart.index, df_chart['price'], color='blue', label='Price')
plt.plot(df_chart.index, df_chart['sma7'], color='red', label='sma7')
plt.plot(df_chart.index, df_chart['sma25'], color='green', label='sma25')
plt.plot(df_chart.index, df_chart['sma50'], color='orange', label='sma50')
plt.plot(df_chart.index, df_chart['ema7'], color='pink', label='ema7')
plt.plot(df_chart.index, df_chart['ema25'], color='gray', label='ema25')
plt.plot(df_chart.index, df_chart['ema50'], color='brown', label='ema50')
plt.title('1-Minute Historical Data of Bitcoin Price', fontsize=15)
plt.ylabel('Bitcoin Price')
plt.xlabel('Time')
plt.legend()

tick_values = pd.date_range(start=df_chart.index[0], end=df_chart.index[-1], freq='30T')
tick_labels = [date.strftime('%Y-%m-%d %H:%M') for date in tick_values]
plt.xticks(tick_values, tick_labels, rotation=45)

plt.show()

# %%
#drop NAN rows
df = df.drop(df.index[:50])

feature_df = df.iloc[:,1:9]

# %%
feature_df
# Out:
#          -1min          sma7         sma25         sma50          ema7  \
# 50    30271.42  30293.747671  30280.362618  30270.983772  30282.120339
# 51    30251.01  30285.473718  30278.581314  30270.280697  30270.547754
# 52    30235.83  30278.997473  30277.043661  30269.677883  30262.945815
# 53    30240.14  30276.200691  30276.338715  30269.472725  30262.064362
# 54    30259.42  30272.376306  30275.262366  30269.071870  30258.905771
# ...        ...           ...           ...           ...           ...
# 1996  30512.85  30513.616485  30486.927322  30452.803016  30518.259932
# 1997  30516.24  30513.265558  30487.896629  30453.970156  30516.484949
# 1998  30511.16  30512.064764  30488.575164  30454.987953  30513.578712
# 1999  30504.86  30510.682655  30489.127758  30455.935994  30510.781534
# 2000  30502.39  30509.499419  30489.658647  30456.865274  30508.686150
#
#              ema25         ema50     price
# 50    30293.132637  30270.592129  30251.01
# 51    30288.724741  30269.228909  30235.83
# 52    30284.987454  30268.088167  30240.14
# 53    30283.020726  30267.748239  30259.42
# 54    30280.436824  30267.029877  30249.43
# ...            ...           ...       ...
# 1996  30503.266014  30486.248963  30516.24
# 1997  30503.873244  30487.225866  30511.16
# 1998  30503.949148  30487.917401  30504.86
# 1999  30503.829213  30488.484954  30502.39
# 2000  30503.719274  30489.030642  30502.40
#
# [1951 rows x 8 columns]

# %%
#Feature Scaling using StandardScaler
scaler = StandardScaler()
df_ft = scaler.fit_transform(feature_df.values)
df_ft = pd.DataFrame(columns=feature_df. columns,
                    data=df_ft,
                    index=feature_df.index)

# %%
df_ft
# Out:
#          -1min      sma7     sma25     sma50      ema7     ema25     ema50  \
# 50   -1.199563 -1.105050 -1.179454 -1.248539 -1.155213 -1.112024 -1.223393
# 51   -1.290908 -1.142342 -1.187640 -1.251865 -1.207209 -1.132017 -1.229657
# 52   -1.358846 -1.171532 -1.194707 -1.254716 -1.241365 -1.148969 -1.234899
# 53   -1.339557 -1.184138 -1.197946 -1.255687 -1.245325 -1.157890 -1.236461
# 54   -1.253269 -1.201375 -1.202893 -1.257583 -1.259517 -1.169611 -1.239762
# ...        ...       ...       ...       ...       ...       ...       ...
# 1996 -0.119037 -0.114066 -0.230147 -0.388410 -0.094234 -0.158876 -0.232436
# 1997 -0.103865 -0.115648 -0.225692 -0.382889 -0.102209 -0.156121 -0.227947
# 1998 -0.126601 -0.121060 -0.222574 -0.378074 -0.115267 -0.155777 -0.224769
# 1999 -0.154797 -0.127289 -0.220035 -0.373589 -0.127835 -0.156321 -0.222161
# 2000 -0.165851 -0.132622 -0.217595 -0.369193 -0.137249 -0.156820 -0.219654
#
#          price
# 50   -1.291905
# 51   -1.359868
# 52   -1.340572
# 53   -1.254253
# 54   -1.298979
# ...        ...
# 1996 -0.104433
# 1997 -0.127177
# 1998 -0.155383
# 1999 -0.166441
# 2000 -0.166397
#
# [1951 rows x 8 columns]

# %%
def lstm_split(data, n_steps):
    X, y = [], []
    for i in range(len(data) - n_steps + 1):
        X.append (data[i:i + n_steps, : - 1])
        y.append(data[i + n_steps - 1, - 1])
    return np.array(X), np.array(y)

# %%
X1, y1 = lstm_split(df_ft.values, n_steps=50)

# %%
X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size=0.3, random_state=42)

# %%
print(X_train.shape, y_train.shape)
# Out:
# (1331, 50, 7) (1331,)

# %%
# Out:
# array([[[ 1.15160795,  1.16176739,  1.23423891, ...,  1.1559654 ,
#           1.18984658,  1.23516596],
#         [ 1.18141492,  1.16701211,  1.23410273, ...,  1.16530662,
#           1.19131945,  1.23502082],
#         [ 1.18772541,  1.17898304,  1.23610623, ...,  1.18535351,
#           1.19672994,  1.23697348],
#         ...,
#         [ 1.2181142 ,  1.18777059,  1.19518502, ...,  1.20737466,
#           1.17656739,  1.19603379],
#         [ 1.20509043,  1.19852737,  1.19924524, ...,  1.2199598 ,
#           1.18406171,  1.20000549],
#         [ 1.25185963,  1.21320758,  1.2047019 , ...,  1.23892385,
#           1.19393836,  1.20534952]],
#
#        [[ 1.22397713,  1.31448939,  1.28355615, ...,  1.32106671,
#           1.2989113 ,  1.28312603],
#         [ 1.38791549,  1.3303425 ,  1.29070483, ...,  1.34569969,
#           1.30956602,  1.2901749 ],
#         [ 1.41311268,  1.3414455 ,  1.29685799, ...,  1.35983866,
#           1.31805433,  1.29625178],
#         ...,
#         [ 0.50601396,  0.65350419,  0.98930522, ...,  0.56764664,
#           0.8081487 ,  0.99431299],
#         [ 0.56549364,  0.63371994,  0.97109079, ...,  0.55373725,
#           0.7860732 ,  0.97628774],
#         [ 0.50905732,  0.61101859,  0.95196518, ...,  0.53328578,
#           0.76258348,  0.95736199]],
#
#        [[ 1.90112355,  1.7096942 ,  1.50407606, ...,  1.79182084,
#           1.60633398,  1.50073413],
#         [ 1.85663686,  1.76044321,  1.52848539, ...,  1.85813262,
#           1.64284512,  1.52481594],
#         [ 2.04809968,  1.76957204,  1.54210564, ...,  1.84790714,
#           1.65792253,  1.53833436],
#         ...,
#         [ 1.27249179,  1.6012009 ,  1.75013692, ...,  1.47281032,
#           1.70900201,  1.7493024 ],
#         [ 1.25091977,  1.5658704 ,  1.73570319, ...,  1.44167012,
#           1.68257049,  1.7352083 ],
#         [ 1.34204139,  1.53969507,  1.72301962, ...,  1.42548133,
#           1.66039826,  1.72281657]],
#
#        ...,
#
#        [[ 1.16087228,  1.13179759,  1.16447081, ...,  1.13657527,
#           1.16003949,  1.16237293],
#         [ 1.25508201,  1.15988678,  1.1724251 , ...,  1.18314744,
#           1.17386448,  1.17027754],
#         [ 1.3167547 ,  1.17543182,  1.1776255 , ...,  1.20319345,
#           1.18200286,  1.17548454],
#         ...,
#         [ 0.39506578,  0.40578041,  0.72549729, ...,  0.37266435,
#           0.52925291,  0.73139043],
#         [ 0.37810356,  0.39864341,  0.71134239, ...,  0.36782718,
#           0.51630719,  0.71731125],
#         [ 0.3509819 ,  0.3922298 ,  0.69766911, ...,  0.36368262,
#           0.50419679,  0.7037013 ]],
#
#        [[-0.76154326, -0.71505222, -0.61392497, ..., -0.72981063,
#          -0.68420583, -0.61033121],
#         [-0.74185096, -0.72906062, -0.62217865, ..., -0.75034508,
#          -0.69430013, -0.61852838],
#         [-0.80974463, -0.73940662, -0.62962791, ..., -0.76284791,
#          -0.70271775, -0.62593917],
#         ...,
#         [-1.01038226, -1.047782  , -1.00781415, ..., -1.0228816 ,
#          -1.06107584, -1.0035848 ],
#         [-1.02815008, -1.04580128, -1.00931797, ..., -1.02517654,
#          -1.05927358, -1.00518819],
#         [-1.02900043, -1.04862355, -1.01205211, ..., -1.03478299,
#          -1.06005935, -1.00799369]],
#
#        [[-0.88018934, -0.90203341, -0.98839831, ..., -0.87835513,
#          -0.94129246, -0.9883032 ],
#         [-0.87034319, -0.89635495, -0.98367862, ..., -0.87400815,
#          -0.93541755, -0.98364391],
#         [-0.85857257, -0.8851648 , -0.97734252, ..., -0.85971757,
#          -0.9265682 , -0.97739778],
#         ...,
#         [-0.73840481, -0.72522153, -0.80856202, ..., -0.71657574,
#          -0.7536682 , -0.8095088 ],
#         [-0.71786217, -0.72108136, -0.80426357, ..., -0.71129292,
#          -0.74937184, -0.80522253],
#         [-0.69369435, -0.69624596, -0.79405972, ..., -0.67019602,
#          -0.73387077, -0.79514698]]])

# %% [markdown]
# ## Sequential model

# %%
model = Sequential ()
model. add(LSTM(units = 100, return_sequences= True, input_shape = (X_train.shape[1], X_train.shape[2])))
model. add (Dropout (0.2))
model. add (LSTM(units = 50, return_sequences= True))
model. add (Dropout (0.2))
model. add(LSTM(units = 100, return_sequences= True))
model. add(Dropout (0.2))
model.add(LSTM(units = 50))
model.add(Dropout (0.2))
model.add(Dense (units=1))

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])

# %% [markdown]
# ## Summary

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 100)           43200
#
#  dropout (Dropout)           (None, 50, 100)           0
#
#  lstm_1 (LSTM)               (None, 50, 50)            30200
#
#  dropout_1 (Dropout)         (None, 50, 50)            0
#
#  lstm_2 (LSTM)               (None, 50, 100)           60400
#
#  dropout_2 (Dropout)         (None, 50, 100)           0
#
#  lstm_3 (LSTM)               (None, 50)                30200
#
#  dropout_3 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 164,051
# Trainable params: 164,051
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train

# %%
model.fit(X_train, y_train, epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 42/42 [==============================] - 34s 247ms/step - loss: 0.1451 - accuracy: 0.0000e+00
# Epoch 2/50
# 42/42 [==============================] - 6s 133ms/step - loss: 0.0534 - accuracy: 0.0000e+00
# Epoch 3/50
# 42/42 [==============================] - 5s 124ms/step - loss: 0.0460 - accuracy: 0.0000e+00
# Epoch 4/50
# 42/42 [==============================] - 5s 115ms/step - loss: 0.0456 - accuracy: 0.0000e+00
# Epoch 5/50
# 42/42 [==============================] - 5s 110ms/step - loss: 0.0380 - accuracy: 0.0000e+00
# Epoch 6/50
# 42/42 [==============================] - 4s 102ms/step - loss: 0.0397 - accuracy: 0.0000e+00
# Epoch 7/50
# 42/42 [==============================] - 4s 99ms/step - loss: 0.0403 - accuracy: 0.0000e+00
# Epoch 8/50
# 42/42 [==============================] - 4s 99ms/step - loss: 0.0337 - accuracy: 0.0000e+00
# Epoch 9/50
# 42/42 [==============================] - 4s 99ms/step - loss: 0.0317 - accuracy: 0.0000e+00
# Epoch 10/50
# 42/42 [==============================] - 4s 97ms/step - loss: 0.0307 - accuracy: 0.0000e+00
# Epoch 11/50
# 42/42 [==============================] - 4s 97ms/step - loss: 0.0369 - accuracy: 0.0000e+00
# Epoch 12/50
# 42/42 [==============================] - 4s 98ms/step - loss: 0.0325 - accuracy: 0.0000e+00
# Epoch 13/50
# 42/42 [==============================] - 4s 100ms/step - loss: 0.0293 - accuracy: 0.0000e+00
# Epoch 14/50
# 42/42 [==============================] - 4s 96ms/step - loss: 0.0277 - accuracy: 0.0000e+00
# Epoch 15/50
# 42/42 [==============================] - 4s 99ms/step - loss: 0.0282 - accuracy: 0.0000e+00
# Epoch 16/50
# 42/42 [==============================] - 4s 99ms/step - loss: 0.0251 - accuracy: 0.0000e+00
# Epoch 17/50
# 42/42 [==============================] - 4s 97ms/step - loss: 0.0255 - accuracy: 0.0000e+00
# Epoch 18/50
# 42/42 [==============================] - 4s 100ms/step - loss: 0.0251 - accuracy: 0.0000e+00
# Epoch 19/50
# 42/42 [==============================] - 4s 95ms/step - loss: 0.0255 - accuracy: 0.0000e+00
# Epoch 20/50
# 42/42 [==============================] - 4s 97ms/step - loss: 0.0247 - accuracy: 0.0000e+00
# Epoch 21/50
# 42/42 [==============================] - 4s 94ms/step - loss: 0.0274 - accuracy: 0.0000e+00
# Epoch 22/50
# 42/42 [==============================] - 4s 96ms/step - loss: 0.0236 - accuracy: 0.0000e+00
# Epoch 23/50
# 42/42 [==============================] - 4s 96ms/step - loss: 0.0221 - accuracy: 0.0000e+00
# Epoch 24/50
# 42/42 [==============================] - 4s 96ms/step - loss: 0.0242 - accuracy: 0.0000e+00
# Epoch 25/50
# 42/42 [==============================] - 4s 93ms/step - loss: 0.0224 - accuracy: 0.0000e+00
# Epoch 26/50
# 42/42 [==============================] - 4s 98ms/step - loss: 0.0219 - accuracy: 0.0000e+00
# Epoch 27/50
# 42/42 [==============================] - 4s 95ms/step - loss: 0.0213 - accuracy: 0.0000e+00
# Epoch 28/50
# 42/42 [==============================] - 4s 96ms/step - loss: 0.0209 - accuracy: 0.0000e+00
# Epoch 29/50
# 42/42 [==============================] - 4s 97ms/step - loss: 0.0219 - accuracy: 0.0000e+00
# Epoch 30/50
# 42/42 [==============================] - 4s 99ms/step - loss: 0.0209 - accuracy: 0.0000e+00
# Epoch 31/50
# 42/42 [==============================] - 4s 94ms/step - loss: 0.0208 - accuracy: 0.0000e+00
# Epoch 32/50
# 42/42 [==============================] - 4s 93ms/step - loss: 0.0217 - accuracy: 0.0000e+00
# Epoch 33/50
# 42/42 [==============================] - 4s 94ms/step - loss: 0.0186 - accuracy: 0.0000e+00
# Epoch 34/50
# 42/42 [==============================] - 4s 95ms/step - loss: 0.0224 - accuracy: 0.0000e+00
# Epoch 35/50
# 42/42 [==============================] - 5s 110ms/step - loss: 0.0204 - accuracy: 0.0000e+00
# Epoch 36/50
# 42/42 [==============================] - 5s 126ms/step - loss: 0.0179 - accuracy: 0.0000e+00
# Epoch 37/50
# 42/42 [==============================] - 5s 107ms/step - loss: 0.0173 - accuracy: 0.0000e+00
# Epoch 38/50
# 42/42 [==============================] - 4s 102ms/step - loss: 0.0196 - accuracy: 0.0000e+00
# Epoch 39/50
# 42/42 [==============================] - 4s 102ms/step - loss: 0.0166 - accuracy: 0.0000e+00
# Epoch 40/50
# 42/42 [==============================] - 4s 101ms/step - loss: 0.0183 - accuracy: 0.0000e+00
# Epoch 41/50
# 42/42 [==============================] - 4s 100ms/step - loss: 0.0166 - accuracy: 0.0000e+00
# Epoch 42/50
# 42/42 [==============================] - 4s 102ms/step - loss: 0.0168 - accuracy: 0.0000e+00
# Epoch 43/50
# 42/42 [==============================] - 4s 99ms/step - loss: 0.0171 - accuracy: 0.0000e+00
# Epoch 44/50
# 42/42 [==============================] - 4s 102ms/step - loss: 0.0154 - accuracy: 0.0000e+00
# Epoch 45/50
# 42/42 [==============================] - 4s 99ms/step - loss: 0.0152 - accuracy: 0.0000e+00
# Epoch 46/50
# 42/42 [==============================] - 4s 97ms/step - loss: 0.0157 - accuracy: 0.0000e+00
# Epoch 47/50
# 42/42 [==============================] - 4s 98ms/step - loss: 0.0154 - accuracy: 0.0000e+00
# Epoch 48/50
# 42/42 [==============================] - 4s 104ms/step - loss: 0.0157 - accuracy: 0.0000e+00
# Epoch 49/50
# 42/42 [==============================] - 4s 106ms/step - loss: 0.0151 - accuracy: 0.0000e+00
# Epoch 50/50
# 42/42 [==============================] - 4s 107ms/step - loss: 0.0144 - accuracy: 0.0000e+00

# %%
# model.save('model_006.h5')
# loaded_model = keras.models.load_model('model_006.h5')

# %% [markdown]
# ## Evaluate

# %%
y_pred = model.predict(X_test)
# Out:
# 18/18 [==============================] - 2s 35ms/step

# %%
error_rates = (y_test.reshape(-1, 1) - y_pred) / y_test.reshape(-1, 1) * 100
average_error_rate = np.sum(error_rates)/len(error_rates)
plt.plot(error_rates)
plt.text(120,-55, f'{average_error_rate:.2f}%', fontsize = 22, bbox = dict(facecolor = 'red', alpha = 0.3))
plt.title('Error Rate')
plt.xlabel('Time')
plt.ylabel('Error')
plt.show()

# %%
y_test_index = range(len(y_test))

y_test_series = pd.Series(y_test.reshape(-1,), index=y_test_index)
y_pred_series = pd.Series(y_pred.reshape(-1,), index=y_test_index)

plt.scatter(y_test_series.index, y_test_series, color='red', label='Real Price', s=3)
plt.scatter(y_pred_series.index, y_pred_series, color='blue', label='Predicted Price', s=3)
plt.title('Bitcoin Price Prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
